# %%
from skimage.transform import pyramid_gaussian
import argparse
import cv2
import time
import numpy as np
import glob
from matplotlib import pyplot as plt

# %%
DEBUG = False
stop_sign = cv2.imread("data/stop_sign.png")
stop_sign = cv2.resize(stop_sign, (32, 32))

def sliding_window(image, step_size, window_size):
    for y in range(0, image.shape[0], step_size):
        for x in range(0, image.shape[1], step_size):
            yield (x, y, image[y:y+window_size[1], x:x+window_size[1]])
            
            

def meanSquareError(img1, img2):
    assert img1.shape == img2.shape, "Images must be the same shape."
    error = np.sum((img1.astype("float") - img2.astype("float")) ** 2)
    error = error/float(img1.shape[0] * img1.shape[1] * img1.shape[2])
    return error

def compareImages(img1, img2):
    return 1./meanSquareError(img1, img2)

def get_ssim(image, target, name, debug = False):
    start = time.time()
    max_ssim = -1
    max_img = None
    max_bbox = []  
    if image.shape[0] != 320 and image.shape[1] != 240:
        image = cv2.resize(image, (320, 240))
    
    while image.shape[0] > 32 and  image.shape[1] > 32:
        image = cv2.pyrDown(image)
        for (x, y, window) in sliding_window(image, step_size=2, window_size=(32, 32)):
            if window.shape[0] != 32 or window.shape[1] != 32:
                continue
            ssim = compareImages(stop_sign, image[y:y+32, x:x+32])
            if ssim > max_ssim:
                max_ssim = ssim
                max_img = image.copy()
                max_bbox = [(x, y), (x + 32, y + 32)] 
            if debug:
                clone = image.copy()
                cv2.rectangle(clone, (x, y), (x + 32, y + 32), (255, 0, 0), 2)
                cv2.imshow("Window",clone)
                cv2.waitKey(1)
                time.sleep(0.025)
    if debug and max_ssim>-1:
        if max_ssim > 8e-5 
            cv2.rectangle(max_img, max_bbox[0], max_bbox[1], (0, 0, 255), 2)
        else:
            cv2.rectangle(max_img, max_bbox[0], max_bbox[1], (0, 255, 0), 2)
        cv2.imwrite("{}.png".format(name), max_img)
        cv2.destroyAllWindows()
    end = time.time()
    return max_ssim, end-start

# %%
files = glob.glob('./data/stop_sign_data/*')
exec_times = []
ssim = []
for file in files:
    img = cv2.imread(file)
    a, b = get_ssim(img, stop_sign, file.split('\\')[-1], debug=False)
    exec_times.append(b)
    ssim.append(a)
# Out:
# 1.jpg 7.415825850337771e-05 0.14560866355895996
# 10.jpg 6.0482900438589625e-05 0.15259265899658203
# 100.jpg 6.627184009847581e-05 0.13463878631591797
# 101.jpg 6.495402303905665e-05 0.11767911911010742
# 102.jpg 6.311163795450087e-05 0.1117098331451416
# 103.jpg 6.26652663808271e-05 0.15857601165771484
# 104.jpg 6.242297458072264e-05 0.15558385848999023
# 105.jpg 7.119668557179699e-05 0.13463783264160156
# 106.jpg 6.325091154817107e-05 0.13065075874328613
# 107.jpg 6.276643683294699e-05 0.11768436431884766
# 108.jpg 6.563775216851365e-05 0.1197049617767334
# 109.jpg 6.563775216851365e-05 0.14461302757263184
# 11.jpg 7.126083309063591e-05 0.16255974769592285
# 110.jpg 6.366351445230167e-05 0.1864938735961914
# 111.jpg 6.995261165980696e-05 0.11170220375061035
# 112.jpg 5.997446165599562e-05 0.14760780334472656
# 113.jpg 6.127519057092899e-05 0.14361858367919922
# 114.jpg 6.476719850052129e-05 0.15358948707580566
# 115.jpeg 6.175172393747083e-05 0.1805248260498047
# 116.jpg 6.385982502324793e-05 0.1904909610748291
# 117.JPG 6.258895291941607e-05 0.45819544792175293
